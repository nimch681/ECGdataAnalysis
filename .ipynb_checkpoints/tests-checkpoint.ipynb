# %%
from codes.python import load_database,ECG_denoising
from codes.python import QRS_detector
import numpy as np
from scipy import signal
from scipy.signal import savgol_filter
import operator
from numpy import array
import sys
import csv
import os
import matplotlib.pyplot as plt
import wfdb
from wfdb import processing, plot
from codes.python import heartbeat_segmentation as shs
from sklearn.decomposition import PCA
from sklearn import svm
from sklearn.preprocessing import normalize
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
import pandas as pd
import pywt
from biosppy.signals import ecg
from sklearn import metrics
#import waipy
import operator
from codes.python import ecg_waveform_extractor as waveform
import time as system_time
from scipy import stats
import warnings
import termcolor as colored

# %%
def average(numbers):
    return float(sum(numbers)) / len(numbers)

# %%
mitdb = load_database.load_mitdb()
mitdb.segment_beats()
# Out:
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/100
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/100.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/100.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/100pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/101
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/101.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/101.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/101pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/102
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/102.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/102.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/102pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/103
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/103.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/103.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/103pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/104
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/104.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/104.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/104pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/105
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/105.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/105.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/105pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/106
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/106.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/106.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/106pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/107
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/107.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/107.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/107pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/108
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/108.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/108.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/108pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/109
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/109.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/109.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/109pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/111
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/111.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/111.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/111pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/112
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/112.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/112.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/112pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/113
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/113.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/113.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/113pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/114
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/114.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/114.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/114pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/115
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/115.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/115.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/115pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/116
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/116.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/116.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/116pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/117
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/117.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/117.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/117pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/118
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/118.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/118.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/118pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/119
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/119.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/119.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/119pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/121
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/121.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/121.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/121pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/122
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/122.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/122.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/122pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/123
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/123.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/123.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/123pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/124
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/124.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/124.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/124pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/200
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/200.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/200.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/200pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/201
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/201.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/201.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/201pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/202
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/202.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/202.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/202pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/203
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/203.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/203.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/203pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/205
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/205.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/205.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/205pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/207
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/207.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/207.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/207pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/208
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/208.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/208.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/208pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/209
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/209.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/209.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/209pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/210
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/210.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/210.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/210pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/212
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/212.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/212.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/212pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/213
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/213.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/213.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/213pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/214
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/214.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/214.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/214pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/215
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/215.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/215.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/215pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/217
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/217.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/217.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/217pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/219
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/219.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/219.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/219pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/220
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/220.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/220.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/220pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/221
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/221.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/221.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/221pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/222
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/222.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/222.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/222pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/223
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/223.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/223.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/223pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/228
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/228.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/228.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/228pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/230
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/230.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/230.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/230pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/231
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/231.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/231.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/231pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/232
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/232.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/232.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/232pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/233
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/233.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/233.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/233pt.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/234
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/234.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/234.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/234pt.csv
# Start segmenting records: 100
# Filtered MLII records from : 100
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 100 completes.
# Start segmenting records: 101
# Filtered MLII records from : 101
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 101 completes.
# Start segmenting records: 102
# Filtered MLII records from : 102
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 102 completes.
# Start segmenting records: 103
# Filtered MLII records from : 103
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 103 completes.
# Start segmenting records: 104
# Filtered MLII records from : 104
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 104 completes.
# Start segmenting records: 105
# Filtered MLII records from : 105
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 105 completes.
# Start segmenting records: 106
# Filtered MLII records from : 106
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 106 completes.
# Start segmenting records: 107
# Filtered MLII records from : 107
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 107 completes.
# Start segmenting records: 108
# Filtered MLII records from : 108
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 108 completes.
# Start segmenting records: 109
# Filtered MLII records from : 109
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 109 completes.
# Start segmenting records: 111
# Filtered MLII records from : 111
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 111 completes.
# Start segmenting records: 112
# Filtered MLII records from : 112
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 112 completes.
# Start segmenting records: 113
# Filtered MLII records from : 113
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 113 completes.
# Start segmenting records: 114
# Filtered MLII records from : 114
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 114 completes.
# Start segmenting records: 115
# Filtered MLII records from : 115
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 115 completes.
# Start segmenting records: 116
# Filtered MLII records from : 116
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 116 completes.
# Start segmenting records: 117
# Filtered MLII records from : 117
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 117 completes.
# Start segmenting records: 118
# Filtered MLII records from : 118
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 118 completes.
# Start segmenting records: 119
# Filtered MLII records from : 119
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 119 completes.
# Start segmenting records: 121
# Filtered MLII records from : 121
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 121 completes.
# Start segmenting records: 122
# Filtered MLII records from : 122
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 122 completes.
# Start segmenting records: 123
# Filtered MLII records from : 123
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 123 completes.
# Start segmenting records: 124
# Filtered MLII records from : 124
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 124 completes.
# Start segmenting records: 200
# Filtered MLII records from : 200
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 200 completes.
# Start segmenting records: 201
# Filtered MLII records from : 201
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 201 completes.
# Start segmenting records: 202
# Filtered MLII records from : 202
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 202 completes.
# Start segmenting records: 203
# Filtered MLII records from : 203
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 203 completes.
# Start segmenting records: 205
# Filtered MLII records from : 205
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 205 completes.
# Start segmenting records: 207
# Filtered MLII records from : 207
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 207 completes.
# Start segmenting records: 208
# Filtered MLII records from : 208
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 208 completes.
# Start segmenting records: 209
# Filtered MLII records from : 209
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 209 completes.
# Start segmenting records: 210
# Filtered MLII records from : 210
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 210 completes.
# Start segmenting records: 212
# Filtered MLII records from : 212
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 212 completes.
# Start segmenting records: 213
# Filtered MLII records from : 213
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 213 completes.
# Start segmenting records: 214
# Filtered MLII records from : 214
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 214 completes.
# Start segmenting records: 215
# Filtered MLII records from : 215
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 215 completes.
# Start segmenting records: 217
# Filtered MLII records from : 217
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 217 completes.
# Start segmenting records: 219
# Filtered MLII records from : 219
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 219 completes.
# Start segmenting records: 220
# Filtered MLII records from : 220
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 220 completes.
# Start segmenting records: 221
# Filtered MLII records from : 221
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 221 completes.
# Start segmenting records: 222
# Filtered MLII records from : 222
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 222 completes.
# Start segmenting records: 223
# Filtered MLII records from : 223
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 223 completes.
# Start segmenting records: 228
# Filtered MLII records from : 228
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 228 completes.
# Start segmenting records: 230
# Filtered MLII records from : 230
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 230 completes.
# Start segmenting records: 231
# Filtered MLII records from : 231
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 231 completes.
# Start segmenting records: 232
# Filtered MLII records from : 232
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 232 completes.
# Start segmenting records: 233
# Filtered MLII records from : 233
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 233 completes.
# Start segmenting records: 234
# Filtered MLII records from : 234
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 234 completes.
# Segmenting beats complete

# %%
mit100 = load_database.load_patient_record("mitdb","100")
mit100.set_segmented_beats_r_pos(winL=100,winR=200)
filtere_MLII = mit100.filtered_MLII
beats, poses = shs.segment(filtere_MLII,100,50,50,25)
assert len(beats) == 100
assert max(filtere_MLII[beats]) == filtere_MLII[poses],"max(pos) isn't equal to r_pos "
count = 0
assert shs.check_class_AAMI('N',-1) == 0

for patient in mitdb.patient_records:
    patient.set_Q_S_points_MLII()



    #r_peak_properties
# Out:
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/100
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/100.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/100.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/100pt.csv
# Start segmenting records: 100
# Filtered MLII records from : 100
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 100 completes.
# Processing file: 100
# Finding Q pos
# Finding S pos
# Done proecessing: 100
# Processing file: 101
# Finding Q pos
# Finding S pos
# Done proecessing: 101
# Processing file: 102
# Finding Q pos
# Finding S pos
# Done proecessing: 102
# Processing file: 103
# Finding Q pos
# Finding S pos
# Done proecessing: 103
# Processing file: 104
# Finding Q pos
# Finding S pos
# Done proecessing: 104
# Processing file: 105
# Finding Q pos
# Finding S pos
# Done proecessing: 105
# Processing file: 106
# Finding Q pos
# Finding S pos
# Done proecessing: 106
# Processing file: 107
# Finding Q pos
# Finding S pos
# Done proecessing: 107
# Processing file: 108
# Finding Q pos
# Finding S pos
# Done proecessing: 108
# Processing file: 109
# Finding Q pos
# Finding S pos
# Done proecessing: 109
# Processing file: 111
# Finding Q pos
# Finding S pos
# Done proecessing: 111
# Processing file: 112
# Finding Q pos
# Finding S pos
# Done proecessing: 112
# Processing file: 113
# Finding Q pos
# Finding S pos
# Done proecessing: 113
# Processing file: 114
# Finding Q pos
# Finding S pos
# Done proecessing: 114
# Processing file: 115
# Finding Q pos
# Finding S pos
# Done proecessing: 115
# Processing file: 116
# Finding Q pos
# Finding S pos
# Done proecessing: 116
# Processing file: 117
# Finding Q pos
# Finding S pos
# Done proecessing: 117
# Processing file: 118
# Finding Q pos
# Finding S pos
# Done proecessing: 118
# Processing file: 119
# Finding Q pos
# Finding S pos
# Done proecessing: 119
# Processing file: 121
# Finding Q pos
# Finding S pos
# Done proecessing: 121
# Processing file: 122
# Finding Q pos
# Finding S pos
# Done proecessing: 122
# Processing file: 123
# Finding Q pos
# Finding S pos
# Done proecessing: 123
# Processing file: 124
# Finding Q pos
# Finding S pos
# Done proecessing: 124
# Processing file: 200
# Finding Q pos
# Finding S pos
# Done proecessing: 200
# Processing file: 201
# Finding Q pos
# Finding S pos
# Done proecessing: 201
# Processing file: 202
# Finding Q pos
# Finding S pos
# Done proecessing: 202
# Processing file: 203
# Finding Q pos
# Finding S pos
# Done proecessing: 203
# Processing file: 205
# Finding Q pos
# Finding S pos
# Done proecessing: 205
# Processing file: 207
# Finding Q pos
# Finding S pos
# Done proecessing: 207
# Processing file: 208
# Finding Q pos
# Finding S pos
# Done proecessing: 208
# Processing file: 209
# Finding Q pos
# Finding S pos
# Done proecessing: 209
# Processing file: 210
# Finding Q pos
# Finding S pos
# Done proecessing: 210
# Processing file: 212
# Finding Q pos
# Finding S pos
# Done proecessing: 212
# Processing file: 213
# Finding Q pos
# Finding S pos
# Done proecessing: 213
# Processing file: 214
# Finding Q pos
# Finding S pos
# Done proecessing: 214
# Processing file: 215
# Finding Q pos
# Finding S pos
# Done proecessing: 215
# Processing file: 217
# Finding Q pos
# Finding S pos
# Done proecessing: 217
# Processing file: 219
# Finding Q pos
# Finding S pos
# Done proecessing: 219
# Processing file: 220
# Finding Q pos
# Finding S pos
# Done proecessing: 220
# Processing file: 221
# Finding Q pos
# Finding S pos
# Done proecessing: 221
# Processing file: 222
# Finding Q pos
# Finding S pos
# Done proecessing: 222
# Processing file: 223
# Finding Q pos
# Finding S pos
# Done proecessing: 223
# Processing file: 228
# Finding Q pos
# Finding S pos
# Done proecessing: 228
# Processing file: 230
# Finding Q pos
# Finding S pos
# Done proecessing: 230
# Processing file: 231
# Finding Q pos
# Finding S pos
# Done proecessing: 231
# Processing file: 232
# Finding Q pos
# Finding S pos
# Done proecessing: 232
# Processing file: 233
# Finding Q pos
# Finding S pos
# Done proecessing: 233
# Processing file: 234
# Finding Q pos
# Finding S pos
# Done proecessing: 234

# %%
count = 0
for patient in mitdb.patient_records:
    
    
    print(patient.filename, count)
    count += 1
    assert len(patient.original_R_pos) == len(patient.segmented_R_pos) == len(patient.segmented_beat_time) == len(patient.segmented_beat_index),"Unequal length, should be equal in length"
    assert len(patient.segmented_beat_1) == len(patient.segmented_class_ID) == len(patient.segmented_beat_class),"Unequal lens, should be equal in length"
    
    
    assert len(patient.Q_points) == len(patient.S_points),"Unequal lens, should be equal in length"
    assert len(patient.segmented_R_pos) == len(patient.S_points),"Unequal lens, should be equal in length"
    r_properties = waveform.r_peak_properties_extractor(patient,to_area=False)
    assert len(r_properties["height"]) == len(patient.segmented_R_pos),"Unequal lens, should be equal in length"
    assert average(r_properties["height"]) < 3,"Average height of r_peak for patient "+ patient.filename+ " is greater than 3"
    assert average(r_properties["height"]) > 0.5,"Average height of r_peak for patient " +patient.filename+ " is less than 0.5"
    assert min(r_properties["height"]) >= 0,"Min height of r_peak for patient " +patient.filename+ " is less than 0"
    assert max(r_properties["height"]) < 5,"Max height of r_peak for patient " +patient.filename+ " is greater than 5"
    x ,y  = np.unique(r_properties["height"], return_counts=True) # counting occurrence of each loan
    index = np.where(x==0)
    index = np.asarray(index)
    if(index.size != 0):
        
        if(y[index[0]] > 20):
            warnings.warn("height equal to 0 number is greater then 20 in " + patient.filename + " record with 0 height number of "+ str(y[index[0]]))
        
    
    assert len(r_properties["durations"]) == len(patient.segmented_R_pos),"Unequal lens, should be equal in length"
    assert average(r_properties["durations"]) < 0.09,"Average duration of r_peak for patient "+ patient.filename+ " is greater than 0.09"
    assert average(r_properties["durations"]) > 0.01,"Average durations of r_peak for patient " +patient.filename+ " is less than 0.01"
    assert min(r_properties["durations"]) >= 0,"Min durations of r_peak for patient " +patient.filename+ " is less than 0"
    assert max(r_properties["durations"]) < 0.3,"Max durations of r_peak for patient " +patient.filename+ " is greater than 0.3"
    x ,y  = np.unique(r_properties["durations"], return_counts=True) # counting occurrence of each loan
    index = np.where(x==0)
    index = np.asarray(index)
    if(index.size != 0):
        
        if(y[index[0]] > 20):
            warnings.warn("durations equal to 0 number is greater then 20 in " + patient.filename + " record with 0 durations number of "+ str(y[index[0]]))
        
    
    assert len(r_properties["onset"]) == len(patient.segmented_R_pos),"Unequal lens, should be equal in length"   
    assert len(r_properties["offset"]) == len(patient.segmented_R_pos),"Unequal lens, should be equal in length" 
    
    #print(r_properties["offset"])

    for i in range(0,len(patient.segmented_R_pos)-1):
        assert len(patient.segmented_beat_1[i])==len(patient.segmented_beat_1[i+1]), "Unequal lens, should be equal in length"
        assert len(patient.segmented_beat_time[i]) == len(patient.segmented_beat_time[i+1]), "Unequal lens, should be equal in length"
        assert len(patient.segmented_beat_1[i])==len(patient.segmented_beat_time[i]), "Unequal lens, should be equal in length"
        assert patient.segmented_R_pos[i] <= patient.segmented_R_pos[i+1], "the later r_pos is smaller " + patient.filename + " R_peak: " + str(patient.segmented_R_pos[i]) +" "+  str(patient.segmented_R_pos[i+1])
        assert len(r_properties["amplitudes"][i]) == 10, "The list of amplitudes is not equal to 10 in patient " + patient.filename + " "+ str(len(r_properties["amplitudes"][i]))
        assert r_properties["peaks"][i] <=  patient.segmented_R_pos[i]+6,"the peak position is not in range : Patient " + patient.filename+ " R_peak: " + str(r_properties["peaks"][i])
        assert r_properties["peaks"][i] >=  patient.segmented_R_pos[i]-6,"the peak position is not in range : Patient " + patient.filename+ " R_peak: " + str(r_properties["peaks"][i])
        assert r_properties["peaks"][i] <=  r_properties["peaks"][i+1], "the later peak position is smaller: Patient " + patient.filename+ " R_peak: " + str(r_properties["peaks"][i]) 
        if(r_properties["offset"][i] < r_properties["peaks"][i]):
            warnings.warn("r_peak is larger than offset. File name: "+ patient.filename + ". r_peak: "+ str(r_properties["peaks"][i]))
        if(r_properties["onset"][i] > r_properties["peaks"][i]):
            warnings.warn("onset is larger than r_peak. File name: "+ patient.filename + ". r_peak: "+ str(r_properties["peaks"][i]))
        if(r_properties["onset"][i] > r_properties["onset"][i+1]):
            warnings.warn("the later onset is larger than current onset. File name: "+ patient.filename + ". r_peak: "+ str(r_properties["peaks"][i]))
        if(r_properties["offset"][i] > r_properties["offset"][i+1]):
            warnings.warn("the later offset is larger than current offset. File name: "+ patient.filename + ". r_peak: "+ str(r_properties["peaks"][i]))
        #  assert max()
        #assert r_properties["onset"][i]  <= r_properties["peaks"][i],"the peak is smaller than onset in " + patient.filename + " onset: " + str(r_properties["onset"][i]) +" peak: "+  str(r_properties["peaks"][i]) 
        #assert r_properties["offset"][i] >= r_properties["peaks"][i],"the peak is larger than offset in " + patient.filename + " offset: " + str(r_properties["offset"][i]) +" peak: "+  str(r_properties["peaks"][i])
# Out:
# 100 0
# Patient file:  100 begins
# Patient file:  100 processing end
# 101 1
# Patient file:  101 begins
# Patient file:  101 processing end
# 102 2
# Patient file:  102 begins
# Patient file:  102 processing end
# 103 3
# Patient file:  103 begins
# Patient file:  103 processing end
# 104 4
# Patient file:  104 begins
# Patient file:  104 processing end
# 105 5
# Patient file:  105 begins
# C:\Users\chont\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: UserWarning: height equal to 0 number is greater then 20 in 104 record with 0 height number of [24]
# C:\Users\chont\Anaconda3\lib\site-packages\ipykernel_launcher.py:39: UserWarning: durations equal to 0 number is greater then 20 in 104 record with 0 durations number of [23]
# Patient file:  105 processing end
# 106 6
# Patient file:  106 begins
# C:\Users\chont\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: UserWarning: height equal to 0 number is greater then 20 in 105 record with 0 height number of [50]
# C:\Users\chont\Anaconda3\lib\site-packages\ipykernel_launcher.py:39: UserWarning: durations equal to 0 number is greater then 20 in 105 record with 0 durations number of [46]
# Patient file:  106 processing end
# 107 7
# Patient file:  107 begins
# Patient file:  107 processing end
# 108 8
# Patient file:  108 begins
# Patient file:  108 processing end
# 109 9
# Patient file:  109 begins
# Patient file:  109 processing end
# 111 10
# Patient file:  111 begins
# Patient file:  111 processing end
# 112 11
# Patient file:  112 begins
# Patient file:  112 processing end
# 113 12
# Patient file:  113 begins
# Patient file:  113 processing end
# 114 13
# Patient file:  114 begins
# Patient file:  114 processing end
# 115 14
# Patient file:  115 begins
# Patient file:  115 processing end
# 116 15
# Patient file:  116 begins
# Patient file:  116 processing end
# 117 16
# Patient file:  117 begins
# Patient file:  117 processing end
# 118 17
# Patient file:  118 begins
# Patient file:  118 processing end
# 119 18
# Patient file:  119 begins
# Patient file:  119 processing end
# 121 19
# Patient file:  121 begins
# C:\Users\chont\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: UserWarning: height equal to 0 number is greater then 20 in 119 record with 0 height number of [48]
# C:\Users\chont\Anaconda3\lib\site-packages\ipykernel_launcher.py:39: UserWarning: durations equal to 0 number is greater then 20 in 119 record with 0 durations number of [47]
# Patient file:  121 processing end
# 122 20
# Patient file:  122 begins
# Patient file:  122 processing end
# 123 21
# Patient file:  123 begins
# Patient file:  123 processing end
# 124 22
# Patient file:  124 begins
# Patient file:  124 processing end
# 200 23
# Patient file:  200 begins
# Patient file:  200 processing end
# 201 24
# Patient file:  201 begins
# C:\Users\chont\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: UserWarning: height equal to 0 number is greater then 20 in 200 record with 0 height number of [46]
# C:\Users\chont\Anaconda3\lib\site-packages\ipykernel_launcher.py:39: UserWarning: durations equal to 0 number is greater then 20 in 200 record with 0 durations number of [44]
# Patient file:  201 processing end
# 202 25
# Patient file:  202 begins
# Patient file:  202 processing end
# 203 26
# Patient file:  203 begins
# Patient file:  203 processing end
# 205 27
# Patient file:  205 begins
# C:\Users\chont\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: UserWarning: height equal to 0 number is greater then 20 in 203 record with 0 height number of [36]
# C:\Users\chont\Anaconda3\lib\site-packages\ipykernel_launcher.py:39: UserWarning: durations equal to 0 number is greater then 20 in 203 record with 0 durations number of [32]
# C:\Users\chont\Anaconda3\lib\site-packages\ipykernel_launcher.py:63: UserWarning: the later offset is larger than current offset. File name: 203. r_peak: 329298
# Patient file:  205 processing end
# 207 28
# Patient file:  207 begins
# Patient file:  207 processing end
# 208 29
# Patient file:  208 begins
# C:\Users\chont\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: UserWarning: height equal to 0 number is greater then 20 in 207 record with 0 height number of [115]
# C:\Users\chont\Anaconda3\lib\site-packages\ipykernel_launcher.py:39: UserWarning: durations equal to 0 number is greater then 20 in 207 record with 0 durations number of [110]
# Patient file:  208 processing end
# 209 30
# Patient file:  209 begins
# C:\Users\chont\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: UserWarning: height equal to 0 number is greater then 20 in 208 record with 0 height number of [50]
# C:\Users\chont\Anaconda3\lib\site-packages\ipykernel_launcher.py:39: UserWarning: durations equal to 0 number is greater then 20 in 208 record with 0 durations number of [47]
# Patient file:  209 processing end
# 210 31
# Patient file:  210 begins
# Patient file:  210 processing end
# 212 32
# Patient file:  212 begins
# Patient file:  212 processing end
# 213 33
# Patient file:  213 begins
# Patient file:  213 processing end
# 214 34
# Patient file:  214 begins
# Patient file:  214 processing end
# 215 35
# Patient file:  215 begins
# Patient file:  215 processing end
# 217 36
# Patient file:  217 begins
# Patient file:  217 processing end
# 219 37
# Patient file:  219 begins
# C:\Users\chont\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: UserWarning: height equal to 0 number is greater then 20 in 217 record with 0 height number of [42]
# C:\Users\chont\Anaconda3\lib\site-packages\ipykernel_launcher.py:39: UserWarning: durations equal to 0 number is greater then 20 in 217 record with 0 durations number of [39]
# Patient file:  219 processing end
# 220 38
# Patient file:  220 begins
# C:\Users\chont\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: UserWarning: height equal to 0 number is greater then 20 in 219 record with 0 height number of [22]
# C:\Users\chont\Anaconda3\lib\site-packages\ipykernel_launcher.py:39: UserWarning: durations equal to 0 number is greater then 20 in 219 record with 0 durations number of [21]
# Patient file:  220 processing end
# 221 39
# Patient file:  221 begins
# Patient file:  221 processing end
# 222 40
# Patient file:  222 begins
# Patient file:  222 processing end
# 223 41
# Patient file:  223 begins
# C:\Users\chont\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: UserWarning: height equal to 0 number is greater then 20 in 222 record with 0 height number of [30]
# C:\Users\chont\Anaconda3\lib\site-packages\ipykernel_launcher.py:39: UserWarning: durations equal to 0 number is greater then 20 in 222 record with 0 durations number of [28]
# Patient file:  223 processing end
# 228 42
# Patient file:  228 begins
# Patient file:  228 processing end
# 230 43
# Patient file:  230 begins
# C:\Users\chont\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: UserWarning: height equal to 0 number is greater then 20 in 228 record with 0 height number of [21]
# Patient file:  230 processing end
# 231 44
# Patient file:  231 begins
# C:\Users\chont\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: UserWarning: height equal to 0 number is greater then 20 in 230 record with 0 height number of [35]
# C:\Users\chont\Anaconda3\lib\site-packages\ipykernel_launcher.py:39: UserWarning: durations equal to 0 number is greater then 20 in 230 record with 0 durations number of [26]
# Patient file:  231 processing end
# 232 45
# Patient file:  232 begins
# Patient file:  232 processing end
# 233 46
# Patient file:  233 begins
# Patient file:  233 processing end
# 234 47
# Patient file:  234 begins
# Patient file:  234 processing end

# %%
mit100 = load_database.load_patient_record("mitdb","100")
mit100.set_segmented_beats_r_pos(winL=100,winR=200)
filtere_MLII = mit100.filtered_MLII
sig = mit100.filtered_MLII[0:500]
sig_savgol = savgol_filter(sig,41,9)
# Out:
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/100
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/100.csv
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/csv/100.txt
# C:\Users\chont\OneDrive\Documents\GitHub\ECGdataAnalysis/database/mitdb/p_t_wave/100pt.csv
# Start segmenting records: 100
# Filtered MLII records from : 100
# start segmenting MLII.
# Finished segmenting MLII.
# Segmenting record 100 completes.

# %%
def average(numbers):
    return float(sum(numbers)) / len(numbers)
def peak_properties_extractor(sig,start_point=None,end_point=None,height=None, distance=None, width = None, plateau_size=None):
    sig = sig[start_point:end_point]
    peaks,properties  = np.asarray(signal.find_peaks(sig, height=height, distance=distance,width=width,plateau_size=plateau_size))
    return peaks,properties

def point_transform_to_origin(por,point):
    point_from_origin = por + point 
    return point_from_origin

def origin_to_new_point(por,point_from_origin):
    point = point_from_origin - por
    return point

def peak_duration(time,right_edge, left_edge,point_from_origin):
    right_edge = point_transform_to_origin(point_from_origin,right_edge)
    left_edge = point_transform_to_origin(point_from_origin,left_edge)
    
    return float(time[right_edge]-time[left_edge])

def sub_signal_interval(time, start_point, end_point,point_from_origin):
    start_point = point_transform_to_origin(point_from_origin,start_point)
    end_point = point_transform_to_origin(point_from_origin,end_point)
    
    return float(time[end_point]-time[start_point])

def peak_height(signal, peak, prominence,point_from_origin):
    peak = point_transform_to_origin(point_from_origin,peak)
    height = signal[peak]-(signal[peak] - prominence)
    return height

def area_under_curve(signal,time,samples,point_from_origin):
    samples = [point_transform_to_origin(i,point_from_origin) for i in samples]
    time = np.asarray(time)
    amplitude = np.asarray(signal)
    area = metrics.auc(time[samples],amplitude[samples])
    return area

def amplitude(signal,samples,point_from_origin):
    samples = [point_transform_to_origin(i,point_from_origin) for i in samples]
    signal = np.asarray(signal)
    amplitudes = signal[samples]
    return amplitudes

def find_Q_point(signal,time, R_peaks, time_limit = 0.01,limit=50):
    num_peak = len(R_peaks)
    Q_points = []   
    for i in range(num_peak):
        r_peak = R_peaks[i]
        point = r_peak
        if point-1 >= len(signal):
            
            break
        
        if(signal[point] >= 0 ):
            while point >= R_peaks[i] - limit and signal[point] >= signal[point - 1] or abs(time[r_peak]-time[point]) <= time_limit:             
                point -= 1
                if point >= len(signal):
                    break
        else:
            
            while point >= R_peaks[i] - limit and abs(signal[point]) >= abs(signal[point - 1]) or abs(time[r_peak]-time[point]) <= time_limit:             
                point -= 1
                if point <= len(signal):
                    break
        
        Q_points.append(point)
                        
    return np.asarray(Q_points)

# only works with filtered leads 
def find_S_point(signal,time, R_peaks, time_limit = 0.01, limit=50):
    num_peak = len(R_peaks)
    S_points = []   
    for i in range(num_peak):
        
        r_peak = R_peaks[i]
        point = r_peak
        if point+1 >= len(signal):
           
            break
        
        if(signal[point] >= 0 ):
            while point <= R_peaks[i] + limit and signal[point] >= signal[point + 1] or abs(time[point]-time[r_peak]) <= time_limit:             
                point += 1
                if point >= len(signal):
                   
                    break
        else:
            
            while  point <= R_peaks[i] + limit and abs(signal[point]) >= abs(signal[point + 1]) or abs(time[point]-time[r_peak]) <= time_limit:             
                point += 1
                if point >= len(signal):
                    break
        
        S_points.append(point)
                        
    return np.asarray(S_points)     

def q_s_peak_properties_extractor(patient,time_limit_from_r=0.1,sample_from_R=[5,5], to_area=True,to_savol=True, Order=9,window_len=41, left_limit=50,right_limit=50, distance=1, width=[0,100],plateau_size=[0,100]):
    s_peaks = []
    q_peaks = []
    q_heights = []
    s_heights = []
    durations = []
    areas = []
    onset = []
    offset = []
    amps = []
    promi = []
    sigs = []
    start_points = []
    end_points = []
    
    time = patient.time
    count = 0
    
    
    
    print("Patient file: ",patient.filename, "begins")
    
    if(patient.filtered_MLII == []):
        print("Please filter the signal")
        return
    if(patient.segmented_R_pos == []):
        print("please segment the signal to find R peak")
        return
    
    
    
    q_points = find_Q_point(patient.filtered_MLII,patient.time, patient.segmented_R_pos)
    s_points = find_S_point(patient.filtered_MLII,patient.time, patient.segmented_R_pos)
    for r in patient.segmented_R_pos:
        start_point = r-left_limit
        end_point = r+right_limit
        MLII = []
        sig = []
        peak = None 
        properties = None
        height = 0
        time = patient.time[start_point:end_point] 
        if(patient.filtered_MLII[r] >= 0):
            MLII = patient.filtered_MLII
            sig = MLII[start_point:end_point]
            height = min(sig)   
        else:
            MLII = -patient.filtered_MLII
            sig = MLII[start_point:end_point]
            height = min(sig)   
        
        if(to_savol == True):
            sig = savgol_filter(sig,window_len,Order)
            height = min(sig)
            
        peak,properties = peak_properties_extractor(sig,height=height, distance=distance, width=width, plateau_size=plateau_size)

        old_sig = sig
        old_peaks = peak
        origin_peaks = point_transform_to_origin(start_point,peak)
        
        r_range_peaks = []

        for p in range(0,len(old_peaks)):
            if(origin_peaks[p] >= r-5 and origin_peaks[p] <= r+5):
                r_range_peaks.append(old_peaks[p])
                
        sig = sig[r_range_peaks]
        r_peak = 0
        
        if(len(sig) == 0):
            r_peak = origin_to_new_point(start_point,r)

        else: 
            value = max(sig)
            
            index = np.where(sig==value)
        
            index = int(index[0])
    
            r_peak = r_range_peaks[index]
        
        
        peak,properties= peak_properties_extractor(-old_sig,height=height, distance=distance, width=width, plateau_size=plateau_size)

        #do q points 
        q_point = 0
        temp_point = 0
        previous_point = peak[0]
        for i in range(1,len(peak)):
            
            if peak[i] >= r_peak-5:
                break
            if peak[i] > previous_point:
                temp_point = peak[i]
        
        if((time[origin_to_new_point(start_point,q_points[count])]-time[temp_point])<=time_limit_from_r):   
            q_point = point_transform_to_origin(start_point,temp_point)
            #print(q_point)
        else:
            q_point=q_points[count]
            #print(q_point)
        
        q_peaks.append(q_point)
                
        #do s points
        s_point = 0
        temp_point = 0
        previous_point = peak[0]
        
        for i in range(1,len(peak)):
            if peak[i] < r_peak+5:
                continue
            temp_point = peak[i]
            break
                        
        if((time[temp_point]-time[origin_to_new_point(start_point,s_points[count])])<=time_limit_from_r):
            
            s_point = point_transform_to_origin(start_point,temp_point)
        else:
            s_point=s_points[count]
            print(s_point)
        s_peaks.append(s_point)
        
        
        
        ## do the p wave finding
        
        #pre_r_sig = patient.filtered_MLII[r:patient.segmented_R_pos[count+1]]
        #neg_pre_r_sig
        count = count+1
    
        
    return   q_peaks , s_peaks

# %%
q_points, s_points = q_s_peak_properties_extractor(mit100)
# Out:
# Patient file:  100 begins
# C:\Users\chont\Anaconda3\lib\site-packages\ipykernel_launcher.py:123: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.

# %%
q_points = np.asarray(q_points[0:3])
s_points = np.asarray(s_points[0:3])

# %%
qrs_durations = []
high_qrs = []
for i in range(0, len(mit100.segmented_R_pos)):
    qrs_duration = round(sub_signal_interval(mit100.time, q_points[i], s_points[i],0),3)
    
    qrs_durations.append(qrs_duration)
    if(qrs_duration>0.14):
        print(mit100.segmented_R_pos[i], qrs_duration, q_points[i], s_points[i])
# Out:
# 546793 0.184 546775 546841

# %%
start_point = 150
end_point = 1000
q=546775
s=546841
q_point = origin_to_new_point(start_point,q)
s_point = origin_to_new_point(start_point,s)
annotation = np.asarray([q_point,s_point])
sig = mit100.filtered_MLII[start_point:end_point]
sig = savgol_filter(sig,41,9)
wfdb.plot_items(signal=sig)

# %%
x ,y  = np.unique(qrs_durations, return_counts=True) # counting occurrence of each loan
plt.scatter(x,y)

# %%
        left_ips = np.asarray(properties_savol["left_ips"])
        right_ips = np.asarray(properties_savol["right_ips"])
        left_ips = [int(i) for i in left_ips]
        right_ips = [int(i) for i in right_ips]

        index = np.where(old_peaks==r_peak)
        index = int(index[0])
    
        left_edge = left_ips[index]
        right_edge = right_ips[index]
        duration = round(peak_duration(time=patient.time,right_edge=right_edge, left_edge=left_edge,point_from_origin=start_point),3)
        prominences = np.asarray(properties_savol["prominences"])
        prominence = prominences[index]
        height = round(peak_height(MLII, peak_savol, prominence,0),3)
        peaks.append(peak_savol)
        durations.append(duration)
        promi.append(prominence)
        amp = amplitude(patient.filtered_MLII,list(range(r-sample_from_R[0],r+sample_from_R[1])),0)
        heights.append(height)
        if(to_area==True):
            samples = list(range(left_edge,right_edge+1))
            area = round(area_under_curve(patient.filtered_MLII,time,samples,start_point),3)
            areas.append(area)
        amps.append(amp)
        offset.append(point_transform_to_origin(right_edge+5,start_point))
        onset.append(point_transform_to_origin(left_edge-5,start_point))
        
    properties = {
        "peaks" : peaks,
        "durations" : durations,
        "prominences" : promi,
        "height" : heights,
        "amplitudes" : amps,
        "areas" : areas,
        "onset" : onset,
        "offset" : offset
        }
    print("Patient file: ",patient.filename, "processing end")
    return properties

# %%
def average(numbers):
    return float(sum(numbers)) / len(numbers)
def peak_properties_extractor(sig,start_point=None,end_point=None,height=None, distance=None, width = None, plateau_size=None):
    sig = sig[start_point:end_point]
    peaks,properties  = np.asarray(signal.find_peaks(sig, height=height, distance=distance,width=width,plateau_size=plateau_size))
    return peaks,properties

def point_transform_to_origin(por,point):
    point_from_origin = por + point 
    return point_from_origin

def origin_to_new_point(por,point_from_origin):
    point = point_from_origin - por
    return point

def peak_duration(time,right_edge, left_edge,point_from_origin):
    right_edge = point_transform_to_origin(point_from_origin,right_edge)
    left_edge = point_transform_to_origin(point_from_origin,left_edge)
    
    return float(time[right_edge]-time[left_edge])

def sub_signal_interval(time, start_point, end_point,point_from_origin):
    start_point = point_transform_to_origin(point_from_origin,start_point)
    end_point = point_transform_to_origin(point_from_origin,end_point)
    
    return float(time[end_point]-time[start_point])

def peak_height(signal, peak, prominence,point_from_origin):
    peak = point_transform_to_origin(point_from_origin,peak)
    height = signal[peak]-(signal[peak] - prominence)
    return height

def area_under_curve(signal,time,samples,point_from_origin):
    samples = [point_transform_to_origin(i,point_from_origin) for i in samples]
    time = np.asarray(time)
    amplitude = np.asarray(signal)
    area = metrics.auc(time[samples],amplitude[samples])
    return area

def amplitude(signal,samples,point_from_origin):
    samples = [point_transform_to_origin(i,point_from_origin) for i in samples]
    signal = np.asarray(signal)
    amplitudes = signal[samples]
    return amplitudes

def find_Q_point(signal,time, R_peaks, time_limit = 0.01,limit=50):
    num_peak = len(R_peaks)
    Q_points = []   
    for i in range(num_peak):
        r_peak = R_peaks[i]
        point = r_peak
        if point-1 >= len(signal):
            
            break
        
        if(signal[point] >= 0 ):
            while point >= R_peaks[i] - limit and signal[point] >= signal[point - 1] or abs(time[r_peak]-time[point]) <= time_limit:             
                point -= 1
                if point >= len(signal):
                    break
        else:
            
            while point >= R_peaks[i] - limit and abs(signal[point]) >= abs(signal[point - 1]) or abs(time[r_peak]-time[point]) <= time_limit:             
                point -= 1
                if point <= len(signal):
                    break
        
        Q_points.append(point)
                        
    return np.asarray(Q_points)

# only works with filtered leads 
def find_S_point(signal,time, R_peaks, time_limit = 0.01, limit=50):
    num_peak = len(R_peaks)
    S_points = []   
    for i in range(num_peak):
        
        r_peak = R_peaks[i]
        point = r_peak
        if point+1 >= len(signal):
           
            break
        
        if(signal[point] >= 0 ):
            while point <= R_peaks[i] + limit and signal[point] >= signal[point + 1] or abs(time[point]-time[r_peak]) <= time_limit:             
                point += 1
                if point >= len(signal):
                   
                    break
        else:
            
            while  point <= R_peaks[i] + limit and abs(signal[point]) >= abs(signal[point + 1]) or abs(time[point]-time[r_peak]) <= time_limit:             
                point += 1
                if point >= len(signal):
                    break
        
        S_points.append(point)
                        
    return np.asarray(S_points)     

def p_and_t_peak_properties_extractor(patient,time_limit_from_r=0.1,sample_from_R=[5,5], to_area=True,to_savol=False, Order=9,window_len=31, left_limit=50,right_limit=50, distance=1, width=[0,100],plateau_size=[0,100]):
    peaks = []
    heights = []
    durations = []
    areas = []
    onset = []
    offset = []
    amps = []
    promi = []
    sigs = []
    start_points = []
    end_points = []
    
    
    p_postitives = []
    p_negatives = []
    t_positives = []
    t_negatives = []
    
    
    time = patient.time
    count = 0
    print("Patient file: ",patient.filename, "begins")
    
    if(patient.filtered_MLII == []):
        print("Please filter the signal")
        return
    if(patient.segmented_R_pos == []):
        print("please segment the signal to find R peak")
        return
    
    if(patient.Q_points == []): 
        print("please segment the signal to find Q peak")
        return
    
    if(patient.S_points == []):
        print("please segment the signal to find S peak")
        return
    ##if(patient.Q_points_properites == None): 
       ## print("please segment the signal to find Q peak")
       # return
    
    #if(patient.S_points_properites == None):
        #print("please segment the signal to find S peak")
       # return
        
    
    
    r_peaks = patient.segmented_R_pos
    q_peaks = patient.Q_points
    s_peaks = patient.S_points
    #q_peaks = patient.Q_points_properites["peaks"]
    #s_peaks = patient.S_points_properites["peaks"]
        
    first_r_sig = patient.filtered_MLII[q_peaks[0]-100:q_peaks[0]]
    last_r_sig = patient.filtered_MLII[s_peaks[len(s_peaks)-1]:s_peaks[len(s_peaks)-1]+100]
    
    pre_r_sig = first_r_sig
    start_pre_r = q_peaks[0]-100
    post_r_sig = patient.filtered_MLII[s_peaks[0]:r_peaks[1]]
    start_post_r = s_peaks[0]
    
    for i in range(0,len(r_peaks)):
        ####pre_processing
        
        negative_pre = -pre_r_sig
        
        if(to_savol == True):
            pre_r_sig = savgol_filter(pre_r_sig,window_len,Order)
            negative_pre = savgol_filter(negative_pre,window_len,Order)

        peak,properties= peak_properties_extractor(pre_r_sig, distance=distance, width=width, plateau_size=plateau_size)
        neg_peak,neg_properties= peak_properties_extractor(negative_pre, distance=distance, width=width, plateau_size=plateau_size)
        ########
        #######do operation to find the p wave
        
        abs_peak = [point_transform_to_origin(p, start_pre_r) for p in peak]
        abs_neg_peak = [point_transform_to_origin(p, start_pre_r) for p in neg_peak]
    
        left, right = sudo_k_mean(abs_peak, time)
        neg_left, neg_right = sudo_k_mean(abs_neg_peak, time)
        
        p_pos = highest_peak(right, patient.filtered_MLII)
        p_neg = highest_peak(neg_right,-patient.filtered_MLII)
        
        p_postitives.append(p_pos)
        p_negatives.append(p_neg)
        
        
        ##################################################
        negative_post = -post_r_sig
        
        if(to_savol == True):
            post_r_sig = savgol_filter(post_r_sig,window_len,Order)
            negative_post = savgol_filter(negative_post,window_len,Order)

        peak,properties= peak_properties_extractor(post_r_sig, distance=distance, width=width, plateau_size=plateau_size)
        neg_peak,neg_properties= peak_properties_extractor(negative_post, distance=distance, width=width, plateau_size=plateau_size)
        
        ########
        #######do operation to find the t wave
        abs_peak = [point_transform_to_origin(p, start_post_r) for p in peak]
        abs_neg_peak = [point_transform_to_origin(p, start_post_r) for p in neg_peak]
        #print(len(abs_peak))
        left, right = sudo_k_mean(abs_peak, time)
        neg_left, neg_right = sudo_k_mean(abs_neg_peak, time)
        
        t_pos = highest_peak(left, patient.filtered_MLII)
        t_neg = highest_peak(neg_left,-patient.filtered_MLII)
        
        t_positives.append(t_pos)
        t_negatives.append(t_neg)
        
        ########next wave _________________________________________
        
        if(i == len(r_peaks)-1):
            break
           
        pre_r_sig = patient.filtered_MLII[s_peaks[i]:q_peaks[i+1]]
        if(i==0):
            print(s_peaks[i], q_peaks[i+1])
       # print("before next ",patient.filtered_MLII[s_peaks[i]:q_peaks[i-1]])
        start_pre_r = s_peaks[i]
        if(i == len(r_peaks)-2):
            post_r_sig = last_r_sig
            start_post_r = s_peaks[len(s_peaks)-1]
            
        else:
            post_r_sig = patient.filtered_MLII[s_peaks[i+1]:q_peaks[i+2]]
            start_post_r = s_peaks[i+1]
            
        
        
        
    return p_postitives, p_negatives, t_positives, t_negatives

# %%
def sudo_k_mean(ls, time):
    first_element = ls[0]
    last_element = ls[len(ls)-1]
    
    left = []
    right = []
    
 
    left.append(first_element)
    right.append(last_element)
    for l in range(1, len(ls)-1):
        time_1 = [time[i] for i in left]
        time_2 = [time[i] for i in right]
    
        
        centroid_1 = average(time_1)
       # print(centroid_1, "centroid_1")
        centroid_2 = average(time_2)
       # print(centroid_2, "centroid_2")
       
        point = ls[l]
        time_point = time[point]
       # print(point, "point")
       # print("time", time_point)
        
        diff_1 = abs(time_point-centroid_1)
        diff_2 = abs(time_point-centroid_2)
        
        if(diff_1 > diff_2):
            right.append(point)
        else:
            left.append(point)
        
    return left, right 
        
        
def highest_peak(peaks, signal):
    signal = signal[peaks]
    max_signal = max(signal)
    index = np.where(signal==max_signal)
        
    index = int(index[0])
    
    highest = peaks[index]
    
    return highest

# %%
mit100.set_Q_S_points_MLII()
p_pos, p_neg, t_pos, t_neg = p_and_t_peak_properties_extractor(mit100)
# Out:
# Processing file: 100
# Finding Q pos
# Finding S pos
# Done proecessing: 100
# Patient file:  100 begins
# 380 653
# C:\Users\chont\Anaconda3\lib\site-packages\ipykernel_launcher.py:125: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.
# C:\Users\chont\Anaconda3\lib\site-packages\ipykernel_launcher.py:132: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.
# C:\Users\chont\Anaconda3\lib\site-packages\ipykernel_launcher.py:136: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.

# %%
for i in range(1, len(mit100.segmented_R_pos)-1):
    point_list = list(range(mit100.segmented_R_pos[i-1],mit100.segmented_R_pos[i]))
    assert p_pos[i] in point_list
    assert (p_pos[i+1] in point_list) == False
    assert (p_pos[i-1] in point_list) == False
    assert mit100.segmented_R_pos[i] > p_pos[i]
    assert p_pos[i] < p_pos[i+1]
    assert mit100.segmented_R_pos[i-1] < p_pos[i], str(mit100.segmented_R_pos[i-1]) + " " +  str(p_pos[i])
    
    
    point_list_2 = list(range(mit100.segmented_R_pos[i],mit100.segmented_R_pos[i+1]))
    assert t_pos[i] in point_list_2
    assert (t_pos[i+1] in point_list) == False
    assert (t_pos[i-1] in point_list_2) == False
    assert t_pos[i] < t_pos[i+1]
    assert mit100.segmented_R_pos[i] < t_pos[i]
    assert mit100.segmented_R_pos[i+1] > t_pos[i], str(mit100.segmented_R_pos[i-1]) + " " +  str(p_pos[i])
    #peak,properties= peak_properties_extractor(mit100.filtered_MLII)

# %%
sig = mit100.filtered_MLII[mit100.S_points[1]:Q_points[2]]
peak, properties = np.asarray(peak_properties_extractor(sig))

# %%
wfdb.plot_items(signal=sig, ann_samp=[peak])

# %%
peaks = [point_transform_to_origin(p, mit100.S_points[1]) for p in peak]

left, right = np.asarray(sudo_k_mean(peaks, mit100.time))

# %%
left, right
# Out:
# ([675, 680, 699, 711, 715, 723, 729, 740, 751, 782, 794, 800, 812, 824],
#  [920, 837, 844, 849, 861, 884, 898])

# %%
high = highest_peak(left, mit100.filtered_MLII)

# %%
left = [origin_to_new_point(mit100.S_points[1],p) for p in left]
right = [origin_to_new_point( mit100.S_points[1], p) for p in right]
# Out:
# list

# %%
left = np.asarray(left)
right= np.asarray(right)
wfdb.plot_items(signal=sig, ann_samp=[right])

# %%
# Out:
# array([-0.05330625, -0.05022077, -0.03708099, -0.02315172, -0.01309745,
#        -0.00742569, -0.00475808, -0.00386109, -0.00412956, -0.00491234,
#        -0.00548247, -0.00551282, -0.00583882, -0.00779104, -0.01181733,
#        -0.01658683, -0.02005533, -0.02096644, -0.01979685, -0.01776839,
#        -0.0155349 , -0.01297248, -0.01022603, -0.00837419, -0.00888718,
#        -0.0121613 , -0.01676249, -0.02029578, -0.02117391, -0.01989912,
#        -0.01839584, -0.01854958, -0.02059612, -0.02340642, -0.0256633 ,
#        -0.02703931, -0.02794606, -0.02866267, -0.02875053, -0.02752772,
#        -0.02493392, -0.02178361, -0.01939704, -0.01849454, -0.01852237,
#        -0.01810574, -0.01641122, -0.01400723, -0.01257986, -0.01327134,
#        -0.01529893, -0.01660362, -0.01563274, -0.01290068, -0.01060339,
#        -0.01065585, -0.01297717, -0.01564562, -0.01669205, -0.01587632,
#        -0.01494388, -0.01589128, -0.01912382, -0.02295754, -0.02535123,
#        -0.02576959, -0.02560644, -0.02666661, -0.02937798, -0.03264073,
#        -0.03508168, -0.03654038, -0.0378828 , -0.04004853, -0.04299969,
#        -0.04581013, -0.04765287, -0.04881369, -0.05059614, -0.05403011,
#        -0.05874025, -0.06301028, -0.06544529, -0.06627548, -0.06717204,
#        -0.06957256, -0.07324023, -0.07653874, -0.07807487, -0.07807011,
#        -0.07801271, -0.0791704 , -0.08114468, -0.08211403, -0.08042459,
#        -0.07596613, -0.07000984, -0.06378607, -0.05711959, -0.04883795,
#        -0.03822818, -0.02621286, -0.01501086, -0.00671829, -0.00181582,
#         0.00102765,  0.00356365,  0.00652813,  0.00924025,  0.01081735,
#         0.0114303 ,  0.01252537,  0.01537239,  0.01968114,  0.02351422,
#         0.02508545,  0.02434005,  0.02304154,  0.02303718,  0.02457669,
#         0.02615011,  0.02606383,  0.02437136,  0.0227358 ,  0.02281389,
#         0.0245537 ,  0.02623235,  0.02615138,  0.02438241,  0.02248802,
#         0.02183747,  0.02256682,  0.02360537,  0.02408817,  0.02430797,
#         0.02535451,  0.02776959,  0.03057336,  0.0318254 ,  0.03022588,
#         0.02635184,  0.0222129 ,  0.01953683,  0.01836091,  0.01752329,
#         0.01593982,  0.01371836,  0.01177136,  0.01065844,  0.00988135,
#         0.00837435,  0.00543425,  0.00153615, -0.00192748, -0.00381479,
#        -0.00409963, -0.00410764, -0.00519472, -0.00751074, -0.00974558,
#        -0.01040942, -0.00922846, -0.00757725, -0.006995  , -0.00765256,
#        -0.00822255, -0.00744711, -0.00568867, -0.00454897, -0.00529016,
#        -0.00735211, -0.00889842, -0.00869387, -0.00750131, -0.00738041,
#        -0.00987931, -0.01443497, -0.01882647, -0.02097174, -0.02037303,
#        -0.01823979, -0.01608238, -0.01447658, -0.0129114 , -0.01078909,
#        -0.0084436 , -0.00710867, -0.00777305, -0.0101181 , -0.01258028,
#        -0.01359255, -0.01305852, -0.01225353, -0.01259524, -0.01414698,
#        -0.01558572, -0.01543304, -0.01352224, -0.01094058, -0.00888902,
#        -0.00767204, -0.00674796, -0.00570048, -0.00483716, -0.00495493,
#        -0.00631144, -0.00806729, -0.0084414 , -0.00578095,  0.00049907,
#         0.00934864,  0.01887664,  0.02763412,  0.03534488,  0.04252211,
#         0.04953431,  0.05614619,  0.06197614,  0.06724161,  0.07287824,
#         0.07974266,  0.08759135,  0.09475871,  0.09920673,  0.10010691,
#         0.09836105,  0.09589917,  0.09386981,  0.09176173,  0.08811541,
#         0.08251906,  0.07665297,  0.07360334,  0.07579052,  0.08278409,
#         0.09108108,  0.09583573,  0.09404723,  0.08596134,  0.07427126,
#         0.06159345,  0.04902476,  0.03653777,  0.02450953,  0.01410324,
#         0.00604991, -0.00026262, -0.00621534, -0.01222014, -0.01718521,
#        -0.01978609, -0.02023979, -0.02043135, -0.02244463, -0.02661805,
#        -0.03123787, -0.03401304, -0.03388464, -0.03165121, -0.02906378,
#        -0.02709965, -0.02526946, -0.0223819 , -0.01843286, -0.01527729,
#        -0.01550238, -0.02061697, -0.0305763 , -0.04457285, -0.06202388,
#        -0.08281018, -0.106077  , -0.12836319])

# %%
# Out:
# 361

# %%
t_pos = np.asarray(t_pos[0:10])
t_pos
# Out:
# array([ 518,  782, 1063, 1368, 1652, 1933, 2184, 2539, 2834, 3121],
#       dtype=int64)

# %%
wfdb.plot_items(signal=mit100.filtered_MLII[0:3500], ann_samp = [t_pos])

# %%
sig =  mit100.filtered_MLII[380:653]
peak,properties= peak_properties_extractor(mit100.filtered_MLII[380:653])

# %%
peak
# Out:
# array([ 15,  20,  26,  38,  63,  68,  74,  86,  92, 103, 124, 136, 164],
#       dtype=int64)

# %%
peaks = [point_transform_to_origin(p, 380) for p in peak]

# %%
left, right = np.asarray(sudo_k_mean(peaks, mit100.time))

# %%
high = highest_peak(right, mit100.filtered_MLII)

# %%
ann = np.asarray([480,high, 653-1])
#ann = np.asarray(peak)

# %%
wfdb.plot_items(signal=mit100.filtered_MLII[0:1000], ann_samp=[ann])

# %%
left
# Out:
# [395, 400, 406, 418, 443, 448, 454, 466, 472, 483]

# %%
right
# Out:
# [544, 504, 516]

# %%
peaks
# Out:
# [387,
#  403,
#  410,
#  423,
#  428,
#  434,
#  440,
#  446,
#  470,
#  495,
#  500,
#  506,
#  518,
#  543,
#  548,
#  554,
#  566,
#  572,
#  583,
#  604,
#  616,
#  644]

# %%
len(peaks)
# Out:
# 13
